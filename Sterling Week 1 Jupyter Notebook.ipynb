# %%
print ("Hellow World")
# Out:
# Hellow World

# %%
s = 7
t=45
s/t * 2
# Out:
# 0.3111111111111111

# %%
import numpy
import pandas
# %matplotlib inline
import matplotlib.pylab as plt

# %%
plt.plot((1,4,6), (4,8,3))

# %%
plt.scatter((1,4,6), (4,8,3))

# %% [markdown]
# # Heading
# This is a text cell
